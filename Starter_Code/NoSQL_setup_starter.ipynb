# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'autosaurus', 'config', 'epa', 'fruits_db', 'local', 'petsitly_marketing', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': '1 The Droveway',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'FirstLight Bar & Café',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4587.64041272672,
#  'FHRSID': 1290215,
#  'LocalAuthorityBusinessID': 'PI/000083029',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DH',
#  'RatingDate': '2020-11-09T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6415303a9e36d615850b3a77'),
#  'geocode': {'latitude': '51.150625', 'longitude': '1.378231'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1290215',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
db.establishments.insert_one(
          {
              "BusinessName":"Penang Flavours",
              "BusinessType":"Restaurant/Cafe/Canteen",
              "BusinessTypeID":"",
              "AddressLine1":"Penang Flavours",
              "AddressLine2":"146A Plumstead Rd",
              "AddressLine3":"London",
              "AddressLine4":"",
              "PostCode":"SE18 7DY",
              "Phone":"",
              "LocalAuthorityCode":"511",
              "LocalAuthorityName":"Greenwich",
              "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
              "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
              "scores":{
              "Hygiene":"",
              "Structural":"",
              "ConfidenceInManagement":""
               },
              "SchemeType":"FHRS",
              "geocode":{
              "longitude":"0.08384000",
              "latitude":"51.49014200"
               },
              "RightToReply":"",
              "Distance":4623.9723280747176,
              "NewRatingPending":True
              })

# %%
# Check that the new restaurant was inserted
query = {'BusinessName': {'$in': ["Penang Flavours"]}}

results = establishments.find(query)

for i in range(1):
    pprint(results[i])
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64153d28fe7f0f926d4981e1'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query = {'BusinessType': 'Restaurant/Cafe/Canteen'}
fields = {'BusinessTypeID': 1, 'BusinessType': 1}

results = establishments.find(query, fields)

pprint(results[0])
# Out:
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6415303a9e36d615850b3a77')}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
db.establishments.update_one({"BusinessName":"Penang Flavours"},{"$set":{"BusinessTypeID": 1}})

# %%
# Confirm that the new restaurant was updated
query = {'BusinessName': {'$in': ["Penang Flavours"]}}

results = establishments.find(query)

for i in range(1):
    pprint(results[i])
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64153d28fe7f0f926d4981e1'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
query = {'LocalAuthorityName': 'Dover'}
print("Number of Local Authority Name with Dover:", establishments.count_documents(query))
# Out:
# Number of Local Authority Name with Dover: 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments.delete_many({"LocalAuthorityName": "Dover"})

# %%
# Check if any remaining documents include Dover
query = {'LocalAuthorityName': 'Dover'}
print("Number of Local Authority Name with Dover:", establishments.count_documents(query))
# Out:
# Number of Local Authority Name with Dover: 0

# %%
# Check that other documents remain with 'find_one'
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'Wear Bay Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Wear Bay Bowls Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4591.821311183521,
#  'FHRSID': 647177,
#  'LocalAuthorityBusinessID': 'PI/000041489',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6PY',
#  'RatingDate': '2014-03-31T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': '4',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6415303a9e36d615850b3d55'),
#  'geocode': {'latitude': '51.086058', 'longitude': '1.196408'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/647177',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 5, 'Structural': 5}}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers. Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for latitude and longitude 
establishments.update_many({}, [ {'$set': { "geocode.latitude": {'$toDouble': "$geocode.latitude"},
                                                "geocode.longitude" : {'$toDouble': "$geocode.longitude"}
                                              } 
                                     } ]
                              )

# %%
# Check that the coordinates are now numbers
results = establishments.find({}, ['geocode.longitude', 'geocode.latitude'])
for result in results:
    pprint(result)
# Out:
# {'_id': ObjectId('6415303a9e36d615850b3d55'),
#  'geocode': {'latitude': 51.086058, 'longitude': 1.196408}}
# {'_id': ObjectId('6415303a9e36d615850b3d56'),
#  'geocode': {'latitude': 51.085797, 'longitude': 1.194762}}
# {'_id': ObjectId('6415303a9e36d615850b3d5a'),
#  'geocode': {'latitude': 51.083812, 'longitude': 1.195625}}
# {'_id': ObjectId('6415303a9e36d615850b3d5b'),
#  'geocode': {'latitude': 51.08084, 'longitude': 1.188537}}
# {'_id': ObjectId('6415303a9e36d615850b3d5c'),
#  'geocode': {'latitude': 51.08084, 'longitude': 1.188537}}
# {'_id': ObjectId('6415303a9e36d615850b3d5e'),
#  'geocode': {'latitude': 51.08084, 'longitude': 1.188537}}
# {'_id': ObjectId('6415303a9e36d615850b3d5f'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d61'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d63'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d64'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d65'),
#  'geocode': {'latitude': 51.08084, 'longitude': 1.188537}}
# {'_id': ObjectId('6415303a9e36d615850b3d66'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d68'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d69'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d6b'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d6c'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d6d'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d6e'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d6f'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d71'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d74'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d75'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d76'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d77'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d78'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d79'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d7a'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d7b'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d7c'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d7d'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d7e'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d7f'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d80'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d81'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d82'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d83'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d84'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d85'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d86'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d87'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d88'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d89'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d8a'),
#  'geocode': {'latitude': 51.0805695006979, 'longitude': 1.18794649942731}}
# {'_id': ObjectId('6415303a9e36d615850b3d8c'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'_id': ObjectId('6415303a9e36d615850b3d8d'),
#  'geocode': {'latitude': 51.080446, 'longitude': 1.186825}}
# {'_id': ObjectId('6415303a9e36d615850b3d8e'),
#  'geocode': {'latitude': 51.087887, 'longitude': 1.194306}}
# {'_id': ObjectId('6415303a9e36d615850b3d8f'),
#  'geocode': {'latitude': 51.079613, 'longitude': 1.185368}}
# {'_id': ObjectId('6415303a9e36d615850b3d90'),
#  'geocode': {'latitude': 51.080224, 'longitude': 1.186067}}
# {'_id': ObjectId('6415303a9e36d615850b3d91'),
#  'geocode': {'latitude': 51.079613, 'longitude': 1.185368}}
# {'_id': ObjectId('6415303a9e36d615850b3d92'),
#  'geocode': {'latitude': 51.083232, 'longitude': 1.188902}}
# {'_id': ObjectId('6415303a9e36d615850b3d93'),
#  'geocode': {'latitude': 51.077971, 'longitude': 1.183585}}
# {'_id': ObjectId('6415303a9e36d615850b3d95'),
#  'geocode': {'latitude': 51.080838, 'longitude': 1.186309}}
# {'_id': ObjectId('6415303a9e36d615850b3d97'),
#  'geocode': {'latitude': 51.081735, 'longitude': 1.187056}}
# {'_id': ObjectId('6415303a9e36d615850b3d98'),
#  'geocode': {'latitude': 51.081546, 'longitude': 1.186715}}
# {'_id': ObjectId('6415303a9e36d615850b3d99'),
#  'geocode': {'latitude': 51.0803, 'longitude': 1.184916}}
# {'_id': ObjectId('6415303a9e36d615850b3d9b'),
#  'geocode': {'latitude': 51.07915, 'longitude': 1.184194}}
# {'_id': ObjectId('6415303a9e36d615850b3d9c'),
#  'geocode': {'latitude': 51.07915, 'longitude': 1.184194}}
# {'_id': ObjectId('6415303a9e36d615850b3d9d'),
#  'geocode': {'latitude': 51.086262, 'longitude': 1.190896}}
# {'_id': ObjectId('6415303a9e36d615850b3da0'),
#  'geocode': {'latitude': 51.095015, 'longitude': 1.202055}}
# {'_id': ObjectId('6415303a9e36d615850b3da1'),
#  'geocode': {'latitude': 51.078449, 'longitude': 1.18516}}
# {'_id': ObjectId('6415303a9e36d615850b3da2'),
#  'geocode': {'latitude': 51.079985650005, 'longitude': 1.18628335007084}}
# {'_id': ObjectId('6415303a9e36d615850b3da3'),
#  'geocode': {'latitude': 51.080673, 'longitude': 1.187083}}
# {'_id': ObjectId('6415303a9e36d615850b3da4'),
#  'geocode': {'latitude': 51.080284, 'longitude': 1.186485}}
# {'_id': ObjectId('6415303a9e36d615850b3da5'),
#  'geocode': {'latitude': 51.0818061828613, 'longitude': 1.18601894378662}}
# {'_id': ObjectId('6415303a9e36d615850b3da7'),
#  'geocode': {'latitude': 51.080284, 'longitude': 1.186485}}
# {'_id': ObjectId('6415303a9e36d615850b3da8'),
#  'geocode': {'latitude': 51.0877821, 'longitude': 1.1920251}}
# {'_id': ObjectId('6415303a9e36d615850b3daa'),
#  'geocode': {'latitude': 51.0804748535156, 'longitude': 1.18425798416138}}
# {'_id': ObjectId('6415303a9e36d615850b3dab'),
#  'geocode': {'latitude': 51.0804824829102, 'longitude': 1.18421399593353}}
# {'_id': ObjectId('6415303a9e36d615850b3dac'),
#  'geocode': {'latitude': 51.0804824829102, 'longitude': 1.18421399593353}}
# {'_id': ObjectId('6415303a9e36d615850b3dad'),
#  'geocode': {'latitude': 51.0793, 'longitude': 1.182962}}
# {'_id': ObjectId('6415303a9e36d615850b3dae'),
#  'geocode': {'latitude': 51.079301, 'longitude': 1.182962}}
# {'_id': ObjectId('6415303a9e36d615850b3daf'),
#  'geocode': {'latitude': 51.0809478759766, 'longitude': 1.18431901931763}}
# {'_id': ObjectId('6415303a9e36d615850b3db0'),
#  'geocode': {'latitude': 51.080956, 'longitude': 1.18429}}
# {'_id': ObjectId('6415303a9e36d615850b3db1'),
#  'geocode': {'latitude': 51.080956, 'longitude': 1.18429}}
# {'_id': ObjectId('6415303a9e36d615850b3db2'),
#  'geocode': {'latitude': 51.080956, 'longitude': 1.18429}}
# {'_id': ObjectId('6415303a9e36d615850b3db3'),
#  'geocode': {'latitude': 51.080956, 'longitude': 1.18429}}
# {'_id': ObjectId('6415303a9e36d615850b3db4'),
#  'geocode': {'latitude': 51.080805, 'longitude': 1.183894}}
# {'_id': ObjectId('6415303a9e36d615850b3db5'),
#  'geocode': {'latitude': 51.080804, 'longitude': 1.183893}}
# {'_id': ObjectId('6415303a9e36d615850b3db6'),
#  'geocode': {'latitude': 51.0810258, 'longitude': 1.1835476}}
# {'_id': ObjectId('6415303a9e36d615850b3db7'),
#  'geocode': {'latitude': 51.079905, 'longitude': 1.182875}}
# {'_id': ObjectId('6415303a9e36d615850b3db8'),
#  'geocode': {'latitude': 51.097794, 'longitude': 1.201433}}
# {'_id': ObjectId('6415303a9e36d615850b3db9'),
#  'geocode': {'latitude': 51.080339, 'longitude': 1.182805}}
# {'_id': ObjectId('6415303a9e36d615850b3dba'),
#  'geocode': {'latitude': 51.080339, 'longitude': 1.182805}}
# {'_id': ObjectId('6415303a9e36d615850b3dbb'),
#  'geocode': {'latitude': 51.08034, 'longitude': 1.182805}}
# {'_id': ObjectId('6415303a9e36d615850b3dbc'),
#  'geocode': {'latitude': 51.08034, 'longitude': 1.182805}}
# {'_id': ObjectId('6415303a9e36d615850b3dbd'),
#  'geocode': {'latitude': 51.08034, 'longitude': 1.182805}}
# {'_id': ObjectId('6415303a9e36d615850b3dbe'),
#  'geocode': {'latitude': 51.08034, 'longitude': 1.182805}}
# {'_id': ObjectId('6415303a9e36d615850b3dbf'),
#  'geocode': {'latitude': 51.0917365039471, 'longitude': 1.19522100055125}}
# {'_id': ObjectId('6415303a9e36d615850b3dc1'),
#  'geocode': {'latitude': 51.079889, 'longitude': 1.181832}}
# {'_id': ObjectId('6415303a9e36d615850b3dc2'),
#  'geocode': {'latitude': 51.079532623291, 'longitude': 1.1813759803772}}
# {'_id': ObjectId('6415303a9e36d615850b3dc3'),
#  'geocode': {'latitude': 51.0803409, 'longitude': 1.1822069}}
# {'_id': ObjectId('6415303a9e36d615850b3dc4'),
#  'geocode': {'latitude': 51.0800235, 'longitude': 1.1813097}}
# {'_id': ObjectId('6415303a9e36d615850b3dc5'),
#  'geocode': {'latitude': 51.079542, 'longitude': 1.181365}}
# {'_id': ObjectId('6415303a9e36d615850b3dc6'),
#  'geocode': {'latitude': 51.0797886, 'longitude': 1.1810166}}
# {'_id': ObjectId('6415303a9e36d615850b3dc7'),
#  'geocode': {'latitude': 51.079542, 'longitude': 1.181365}}
# {'_id': ObjectId('6415303a9e36d615850b3dc8'),
#  'geocode': {'latitude': 51.089491, 'longitude': 1.190904}}
# {'_id': ObjectId('6415303a9e36d615850b3dc9'),
#  'geocode': {'latitude': 51.089491, 'longitude': 1.190904}}
# {'_id': ObjectId('6415303a9e36d615850b3dca'),
#  'geocode': {'latitude': 51.080675, 'longitude': 1.181728}}
# {'_id': ObjectId('6415303a9e36d615850b3dcb'),
#  'geocode': {'latitude': 51.0798931, 'longitude': 1.1817077}}
# {'_id': ObjectId('6415303a9e36d615850b3dcc'),
#  'geocode': {'latitude': 51.0806732177734, 'longitude': 1.18172800540924}}
# {'_id': ObjectId('6415303a9e36d615850b3dcd'),
#  'geocode': {'latitude': 51.080675, 'longitude': 1.181728}}
# {'_id': ObjectId('6415303a9e36d615850b3dce'),
#  'geocode': {'latitude': 51.080675, 'longitude': 1.181728}}
# {'_id': ObjectId('6415303a9e36d615850b3dcf'),
#  'geocode': {'latitude': 51.080675, 'longitude': 1.181728}}
# {'_id': ObjectId('6415303a9e36d615850b3dd0'),
#  'geocode': {'latitude': 51.080675, 'longitude': 1.181728}}
# {'_id': ObjectId('6415303a9e36d615850b3dd1'),
#  'geocode': {'latitude': 51.080675, 'longitude': 1.181728}}
# {'_id': ObjectId('6415303a9e36d615850b3dd2'),
#  'geocode': {'latitude': 51.082322, 'longitude': 1.183327}}
# {'_id': ObjectId('6415303a9e36d615850b3dd3'),
#  'geocode': {'latitude': 51.0806941, 'longitude': 1.1817227}}
# {'_id': ObjectId('6415303a9e36d615850b3dd4'),
#  'geocode': {'latitude': 51.080412, 'longitude': 1.182125}}
# {'_id': ObjectId('6415303a9e36d615850b3dd5'),
#  'geocode': {'latitude': 51.0793698, 'longitude': 1.1802781}}
# {'_id': ObjectId('6415303a9e36d615850b3dd6'),
#  'geocode': {'latitude': 51.08164, 'longitude': 1.182609}}
# {'_id': ObjectId('6415303a9e36d615850b3dd7'),
#  'geocode': {'latitude': 51.080412, 'longitude': 1.182125}}
# {'_id': ObjectId('6415303a9e36d615850b3dd8'),
#  'geocode': {'latitude': 51.07954, 'longitude': 1.180437}}
# {'_id': ObjectId('6415303a9e36d615850b3dd9'),
#  'geocode': {'latitude': 51.07954, 'longitude': 1.180437}}
# {'_id': ObjectId('6415303a9e36d615850b3dda'),
#  'geocode': {'latitude': 51.083976, 'longitude': 1.185011}}
# {'_id': ObjectId('6415303a9e36d615850b3ddb'),
#  'geocode': {'latitude': 51.07954, 'longitude': 1.180437}}
# {'_id': ObjectId('6415303a9e36d615850b3ddc'),
#  'geocode': {'latitude': 51.07954, 'longitude': 1.180437}}
# {'_id': ObjectId('6415303a9e36d615850b3ddd'),
#  'geocode': {'latitude': 51.084721, 'longitude': 1.185748}}
# {'_id': ObjectId('6415303a9e36d615850b3dde'),
#  'geocode': {'latitude': 51.078209, 'longitude': 1.179446}}
# {'_id': ObjectId('6415303a9e36d615850b3ddf'),
#  'geocode': {'latitude': 51.0818634033203, 'longitude': 1.18279695510864}}
# {'_id': ObjectId('6415303a9e36d615850b3de0'),
#  'geocode': {'latitude': 51.08164, 'longitude': 1.182609}}
# {'_id': ObjectId('6415303a9e36d615850b3de1'),
#  'geocode': {'latitude': 51.080417, 'longitude': 1.181282}}
# {'_id': ObjectId('6415303a9e36d615850b3de2'),
#  'geocode': {'latitude': 51.0804176330566, 'longitude': 1.18128204345703}}
# {'_id': ObjectId('6415303a9e36d615850b3de3'),
#  'geocode': {'latitude': 51.080417, 'longitude': 1.181282}}
# {'_id': ObjectId('6415303a9e36d615850b3de4'),
#  'geocode': {'latitude': 51.080181, 'longitude': 1.181023}}
# {'_id': ObjectId('6415303a9e36d615850b3de5'),
#  'geocode': {'latitude': 51.08187, 'longitude': 1.182753}}
# {'_id': ObjectId('6415303a9e36d615850b3de6'),
#  'geocode': {'latitude': 51.081494, 'longitude': 1.182356}}
# {'_id': ObjectId('6415303a9e36d615850b3de7'),
#  'geocode': {'latitude': 51.078296, 'longitude': 1.178909}}
# {'_id': ObjectId('6415303a9e36d615850b3de8'),
#  'geocode': {'latitude': 51.078296, 'longitude': 1.178909}}
# {'_id': ObjectId('6415303a9e36d615850b3de9'),
#  'geocode': {'latitude': 51.079799, 'longitude': 1.181482}}
# {'_id': ObjectId('6415303a9e36d615850b3dea'),
#  'geocode': {'latitude': 51.08187, 'longitude': 1.182753}}
# {'_id': ObjectId('6415303a9e36d615850b3deb'),
#  'geocode': {'latitude': 51.0802346, 'longitude': 1.1814856}}
# {'_id': ObjectId('6415303a9e36d615850b3dec'),
#  'geocode': {'latitude': 51.08187, 'longitude': 1.182753}}
# {'_id': ObjectId('6415303a9e36d615850b3ded'),
#  'geocode': {'latitude': 51.079542, 'longitude': 1.181365}}
# {'_id': ObjectId('6415303a9e36d615850b3dee'),
#  'geocode': {'latitude': 51.078296, 'longitude': 1.178909}}
# {'_id': ObjectId('6415303a9e36d615850b3def'),
#  'geocode': {'latitude': 51.0798, 'longitude': 1.181483}}
# {'_id': ObjectId('6415303a9e36d615850b3df0'),
#  'geocode': {'latitude': 51.0802956, 'longitude': 1.1823865}}
# {'_id': ObjectId('6415303a9e36d615850b3df1'),
#  'geocode': {'latitude': 51.078296, 'longitude': 1.178909}}
# {'_id': ObjectId('6415303a9e36d615850b3df2'),
#  'geocode': {'latitude': 51.085454, 'longitude': 1.186241}}
# {'_id': ObjectId('6415303a9e36d615850b3df3'),
#  'geocode': {'latitude': 51.086189, 'longitude': 1.186977}}
# {'_id': ObjectId('6415303a9e36d615850b3df4'),
#  'geocode': {'latitude': 51.0785865783691, 'longitude': 1.17911505699158}}
# {'_id': ObjectId('6415303a9e36d615850b3df5'),
#  'geocode': {'latitude': 51.0798709, 'longitude': 1.1803396}}
# {'_id': ObjectId('6415303a9e36d615850b3df6'),
#  'geocode': {'latitude': 51.0780695, 'longitude': 1.1785097}}
# {'_id': ObjectId('6415303a9e36d615850b3df7'),
#  'geocode': {'latitude': 51.086189, 'longitude': 1.186977}}
# {'_id': ObjectId('6415303a9e36d615850b3df8'),
#  'geocode': {'latitude': 51.078587, 'longitude': 1.179115}}
# {'_id': ObjectId('6415303a9e36d615850b3df9'),
#  'geocode': {'latitude': 51.0802287, 'longitude': 1.1806797}}
# {'_id': ObjectId('6415303a9e36d615850b3dfa'),
#  'geocode': {'latitude': 51.078117, 'longitude': 1.1784815}}
# {'_id': ObjectId('6415303a9e36d615850b3dfb'),
#  'geocode': {'latitude': 51.079632, 'longitude': 1.179729}}
# {'_id': ObjectId('6415303a9e36d615850b3dfc'),
#  'geocode': {'latitude': 51.0781968, 'longitude': 1.1783613}}
# {'_id': ObjectId('6415303a9e36d615850b3dfd'),
#  'geocode': {'latitude': 51.0781968, 'longitude': 1.1783613}}
# {'_id': ObjectId('6415303a9e36d615850b3dfe'),
#  'geocode': {'latitude': 51.0818613, 'longitude': 1.1818685}}
# {'_id': ObjectId('6415303a9e36d615850b3dff'),
#  'geocode': {'latitude': 51.079632, 'longitude': 1.179729}}
# {'_id': ObjectId('6415303a9e36d615850b3e00'),
#  'geocode': {'latitude': 51.0818613, 'longitude': 1.1818685}}
# {'_id': ObjectId('6415303a9e36d615850b3e01'),
#  'geocode': {'latitude': 51.080211, 'longitude': 1.179926}}
# {'_id': ObjectId('6415303a9e36d615850b3e02'),
#  'geocode': {'latitude': 51.083569, 'longitude': 1.183784}}
# {'_id': ObjectId('6415303a9e36d615850b3e04'),
#  'geocode': {'latitude': 51.080211, 'longitude': 1.179925}}
# {'_id': ObjectId('6415303a9e36d615850b3e05'),
#  'geocode': {'latitude': 51.079161, 'longitude': 1.17884}}
# {'_id': ObjectId('6415303a9e36d615850b3e06'),
#  'geocode': {'latitude': 51.078131, 'longitude': 1.178027}}
# {'_id': ObjectId('6415303a9e36d615850b3e07'),
#  'geocode': {'latitude': 51.080315, 'longitude': 1.18039}}
# {'_id': ObjectId('6415303a9e36d615850b3e09'),
#  'geocode': {'latitude': 51.080315, 'longitude': 1.18039}}
# {'_id': ObjectId('6415303a9e36d615850b3e0a'),
#  'geocode': {'latitude': 51.080217, 'longitude': 1.1799178}}
# {'_id': ObjectId('6415303a9e36d615850b3e0b'),
#  'geocode': {'latitude': 51.079482, 'longitude': 1.178962}}
# {'_id': ObjectId('6415303a9e36d615850b3e0c'),
#  'geocode': {'latitude': 51.08472, 'longitude': 1.185748}}
# {'_id': ObjectId('6415303a9e36d615850b3e0d'),
#  'geocode': {'latitude': 51.0816612, 'longitude': 1.1826116}}
# {'_id': ObjectId('6415303a9e36d615850b3e0e'),
#  'geocode': {'latitude': 51.081526, 'longitude': 1.181201}}
# {'_id': ObjectId('6415303a9e36d615850b3e0f'),
#  'geocode': {'latitude': 51.080211, 'longitude': 1.179926}}
# {'_id': ObjectId('6415303a9e36d615850b3e10'),
#  'geocode': {'latitude': 51.079482, 'longitude': 1.178962}}
# {'_id': ObjectId('6415303a9e36d615850b3e11'),
#  'geocode': {'latitude': 51.079481, 'longitude': 1.178961}}
# {'_id': ObjectId('6415303a9e36d615850b3e13'),
#  'geocode': {'latitude': 51.088735, 'longitude': 1.188295}}
# {'_id': ObjectId('6415303a9e36d615850b3e14'),
#  'geocode': {'latitude': 51.083569, 'longitude': 1.183784}}
# {'_id': ObjectId('6415303a9e36d615850b3e15'),
#  'geocode': {'latitude': 51.082867, 'longitude': 1.182136}}
# {'_id': ObjectId('6415303a9e36d615850b3e16'),
#  'geocode': {'latitude': 51.0783483, 'longitude': 1.177752}}
# {'_id': ObjectId('6415303a9e36d615850b3e17'),
#  'geocode': {'latitude': 51.082867, 'longitude': 1.182136}}
# {'_id': ObjectId('6415303a9e36d615850b3e18'),
#  'geocode': {'latitude': 51.081337, 'longitude': 1.180846}}
# {'_id': ObjectId('6415303a9e36d615850b3e19'),
#  'geocode': {'latitude': 51.087132, 'longitude': 1.186371}}
# {'_id': ObjectId('6415303a9e36d615850b3e1a'),
#  'geocode': {'latitude': 51.0806446, 'longitude': 1.1796215}}
# {'_id': ObjectId('6415303a9e36d615850b3e1b'),
#  'geocode': {'latitude': 51.080668, 'longitude': 1.179628}}
# {'_id': ObjectId('6415303a9e36d615850b3e1c'),
#  'geocode': {'latitude': 51.080669, 'longitude': 1.179629}}
# {'_id': ObjectId('6415303a9e36d615850b3e1d'),
#  'geocode': {'latitude': 51.0804496, 'longitude': 1.1794011}}
# {'_id': ObjectId('6415303a9e36d615850b3e1e'),
#  'geocode': {'latitude': 51.080669, 'longitude': 1.179629}}
# {'_id': ObjectId('6415303a9e36d615850b3e20'),
#  'geocode': {'latitude': 51.076896, 'longitude': 1.175486}}
# {'_id': ObjectId('6415303a9e36d615850b3e21'),
#  'geocode': {'latitude': 51.0782127380371, 'longitude': 1.17673301696777}}
# {'_id': ObjectId('6415303a9e36d615850b3e22'),
#  'geocode': {'latitude': 51.078211, 'longitude': 1.176733}}
# {'_id': ObjectId('6415303a9e36d615850b3e23'),
#  'geocode': {'latitude': 51.083108, 'longitude': 1.181896}}
# {'_id': ObjectId('6415303a9e36d615850b3e24'),
#  'geocode': {'latitude': 51.0808513, 'longitude': 1.1794486}}
# {'_id': ObjectId('6415303a9e36d615850b3e25'),
#  'geocode': {'latitude': 51.0810699462891, 'longitude': 1.17957198619843}}
# {'_id': ObjectId('6415303a9e36d615850b3e26'),
#  'geocode': {'latitude': 51.079081, 'longitude': 1.177506}}
# {'_id': ObjectId('6415303a9e36d615850b3e27'),
#  'geocode': {'latitude': 51.081337, 'longitude': 1.180846}}
# {'_id': ObjectId('6415303a9e36d615850b3e28'),
#  'geocode': {'latitude': 51.079081, 'longitude': 1.177506}}
# {'_id': ObjectId('6415303a9e36d615850b3e29'),
#  'geocode': {'latitude': 51.079679, 'longitude': 1.17799}}
# {'_id': ObjectId('6415303a9e36d615850b3e2a'),
#  'geocode': {'latitude': 51.078317, 'longitude': 1.177468}}
# {'_id': ObjectId('6415303a9e36d615850b3e2b'),
#  'geocode': {'latitude': 51.079679, 'longitude': 1.17799}}
# {'_id': ObjectId('6415303a9e36d615850b3e2c'),
#  'geocode': {'latitude': 51.080624, 'longitude': 1.178969}}
# {'_id': ObjectId('6415303a9e36d615850b3e2d'),
#  'geocode': {'latitude': 51.079679, 'longitude': 1.17799}}
# {'_id': ObjectId('6415303a9e36d615850b3e2e'),
#  'geocode': {'latitude': 51.077626, 'longitude': 1.17575}}
# {'_id': ObjectId('6415303a9e36d615850b3e2f'),
#  'geocode': {'latitude': 51.079679, 'longitude': 1.17799}}
# {'_id': ObjectId('6415303a9e36d615850b3e30'),
#  'geocode': {'latitude': 51.076653, 'longitude': 1.174813}}
# {'_id': ObjectId('6415303a9e36d615850b3e31'),
#  'geocode': {'latitude': 51.0776252746582, 'longitude': 1.17575001716614}}
# {'_id': ObjectId('6415303a9e36d615850b3e32'),
#  'geocode': {'latitude': 51.077626, 'longitude': 1.17575}}
# {'_id': ObjectId('6415303a9e36d615850b3e33'),
#  'geocode': {'latitude': 51.077626, 'longitude': 1.17575}}
# {'_id': ObjectId('6415303a9e36d615850b3e34'),
#  'geocode': {'latitude': 51.077626, 'longitude': 1.17575}}
# {'_id': ObjectId('6415303a9e36d615850b3e35'),
#  'geocode': {'latitude': 51.077626, 'longitude': 1.17575}}
# {'_id': ObjectId('6415303a9e36d615850b3e36'),
#  'geocode': {'latitude': 51.087185, 'longitude': 1.185418}}
# {'_id': ObjectId('6415303a9e36d615850b3e37'),
#  'geocode': {'latitude': 51.088735, 'longitude': 1.188295}}
# {'_id': ObjectId('6415303a9e36d615850b3e38'),
#  'geocode': {'latitude': 51.078317, 'longitude': 1.177468}}
# {'_id': ObjectId('6415303a9e36d615850b3e39'),
#  'geocode': {'latitude': 51.0783433, 'longitude': 1.1776046}}
# {'_id': ObjectId('6415303a9e36d615850b3e3a'),
#  'geocode': {'latitude': 51.0824157, 'longitude': 1.1817418}}
# {'_id': ObjectId('6415303a9e36d615850b3e3b'),
#  'geocode': {'latitude': 51.078317, 'longitude': 1.177468}}
# {'_id': ObjectId('6415303a9e36d615850b3e3c'),
#  'geocode': {'latitude': 51.0758056640625, 'longitude': 1.17352676391602}}
# {'_id': ObjectId('6415303a9e36d615850b3e3d'),
#  'geocode': {'latitude': 51.078317, 'longitude': 1.177468}}
# {'_id': ObjectId('6415303a9e36d615850b3e3e'),
#  'geocode': {'latitude': 51.076956, 'longitude': 1.174605}}
# {'_id': ObjectId('6415303a9e36d615850b3e3f'),
#  'geocode': {'latitude': 51.076956, 'longitude': 1.174605}}
# {'_id': ObjectId('6415303a9e36d615850b3e40'),
#  'geocode': {'latitude': 51.0776458, 'longitude': 1.1753663}}
# {'_id': ObjectId('6415303a9e36d615850b3e41'),
#  'geocode': {'latitude': 51.078718, 'longitude': 1.176296}}
# {'_id': ObjectId('6415303a9e36d615850b3e42'),
#  'geocode': {'latitude': 51.078718, 'longitude': 1.176296}}
# {'_id': ObjectId('6415303a9e36d615850b3e43'),
#  'geocode': {'latitude': 51.0788531, 'longitude': 1.1762215}}
# {'_id': ObjectId('6415303a9e36d615850b3e44'),
#  'geocode': {'latitude': 51.078033, 'longitude': 1.17535}}
# {'_id': ObjectId('6415303a9e36d615850b3e45'),
#  'geocode': {'latitude': 51.078513, 'longitude': 1.175897}}
# {'_id': ObjectId('6415303a9e36d615850b3e46'),
#  'geocode': {'latitude': 51.07879, 'longitude': 1.176258}}
# {'_id': ObjectId('6415303a9e36d615850b3e47'),
#  'geocode': {'latitude': 51.078033, 'longitude': 1.17535}}
# {'_id': ObjectId('6415303a9e36d615850b3e48'),
#  'geocode': {'latitude': 51.078033, 'longitude': 1.17535}}
# {'_id': ObjectId('6415303a9e36d615850b3e49'),
#  'geocode': {'latitude': 51.078033, 'longitude': 1.17535}}
# {'_id': ObjectId('6415303a9e36d615850b3e4a'),
#  'geocode': {'latitude': 51.09221, 'longitude': 1.189834}}
# {'_id': ObjectId('6415303a9e36d615850b3e4b'),
#  'geocode': {'latitude': 51.09221, 'longitude': 1.189833}}
# {'_id': ObjectId('6415303a9e36d615850b3e4c'),
#  'geocode': {'latitude': 51.078515, 'longitude': 1.175811}}
# {'_id': ObjectId('6415303a9e36d615850b3e4d'),
#  'geocode': {'latitude': 51.078515, 'longitude': 1.175811}}
# {'_id': ObjectId('6415303a9e36d615850b3e4e'),
#  'geocode': {'latitude': 51.078033, 'longitude': 1.17535}}
# {'_id': ObjectId('6415303a9e36d615850b3e4f'),
#  'geocode': {'latitude': 51.087382, 'longitude': 1.184803}}
# {'_id': ObjectId('6415303a9e36d615850b3e50'),
#  'geocode': {'latitude': 51.0787391662598, 'longitude': 1.17591404914856}}
# {'_id': ObjectId('6415303a9e36d615850b3e51'),
#  'geocode': {'latitude': 51.07873, 'longitude': 1.17584}}
# {'_id': ObjectId('6415303a9e36d615850b3e52'),
#  'geocode': {'latitude': 51.07873, 'longitude': 1.17584}}
# {'_id': ObjectId('6415303a9e36d615850b3e53'),
#  'geocode': {'latitude': 51.07873, 'longitude': 1.17584}}
# {'_id': ObjectId('6415303a9e36d615850b3e54'),
#  'geocode': {'latitude': 51.0806630002457, 'longitude': 1.17725700019713}}
# {'_id': ObjectId('6415303a9e36d615850b3e55'),
#  'geocode': {'latitude': 51.07873, 'longitude': 1.17584}}
# {'_id': ObjectId('6415303a9e36d615850b3e56'),
#  'geocode': {'latitude': 51.0812644958496, 'longitude': 1.17841398715973}}
# {'_id': ObjectId('6415303a9e36d615850b3e57'),
#  'geocode': {'latitude': 51.076647, 'longitude': 1.172728}}
# {'_id': ObjectId('6415303a9e36d615850b3e58'),
#  'geocode': {'latitude': 51.07856, 'longitude': 1.1748}}
# {'_id': ObjectId('6415303a9e36d615850b3e59'),
#  'geocode': {'latitude': 51.088115, 'longitude': 1.18431}}
# {'_id': ObjectId('6415303a9e36d615850b3e5a'),
#  'geocode': {'latitude': 51.076647, 'longitude': 1.172728}}
# {'_id': ObjectId('6415303a9e36d615850b3e5b'),
#  'geocode': {'latitude': 51.088115, 'longitude': 1.18431}}
# {'_id': ObjectId('6415303a9e36d615850b3e5c'),
#  'geocode': {'latitude': 51.088115, 'longitude': 1.18431}}
# {'_id': ObjectId('6415303a9e36d615850b3e5d'),
#  'geocode': {'latitude': 51.088115, 'longitude': 1.18431}}
# {'_id': ObjectId('6415303a9e36d615850b3e5e'),
#  'geocode': {'latitude': 51.079039, 'longitude': 1.174748}}
# {'_id': ObjectId('6415303a9e36d615850b3e5f'),
#  'geocode': {'latitude': 51.088115, 'longitude': 1.18431}}
# {'_id': ObjectId('6415303a9e36d615850b3e60'),
#  'geocode': {'latitude': 51.076647, 'longitude': 1.172728}}
# {'_id': ObjectId('6415303a9e36d615850b3e61'),
#  'geocode': {'latitude': 51.0881644, 'longitude': 1.1842719}}
# {'_id': ObjectId('6415303a9e36d615850b3e62'),
#  'geocode': {'latitude': 51.088333, 'longitude': 1.183925}}
# {'_id': ObjectId('6415303a9e36d615850b3e63'),
#  'geocode': {'latitude': 51.076577, 'longitude': 1.17198}}
# {'_id': ObjectId('6415303a9e36d615850b3e64'),
#  'geocode': {'latitude': 51.089337, 'longitude': 1.18468}}
# {'_id': ObjectId('6415303a9e36d615850b3e65'),
#  'geocode': {'latitude': 51.080171, 'longitude': 1.175782}}
# {'_id': ObjectId('6415303a9e36d615850b3e66'),
#  'geocode': {'latitude': 51.077414, 'longitude': 1.172652}}
# {'_id': ObjectId('6415303a9e36d615850b3e67'),
#  'geocode': {'latitude': 51.0833323, 'longitude': 1.1784191}}
# {'_id': ObjectId('6415303a9e36d615850b3e68'),
#  'geocode': {'latitude': 51.088115, 'longitude': 1.18431}}
# {'_id': ObjectId('6415303a9e36d615850b3e69'),
#  'geocode': {'latitude': 51.076413, 'longitude': 1.172055}}
# {'_id': ObjectId('6415303a9e36d615850b3e6a'),
#  'geocode': {'latitude': 51.077702, 'longitude': 1.172314}}
# {'_id': ObjectId('6415303a9e36d615850b3e6b'),
#  'geocode': {'latitude': 51.076577, 'longitude': 1.17198}}
# {'_id': ObjectId('6415303a9e36d615850b3e6c'),
#  'geocode': {'latitude': 51.077492, 'longitude': 1.173056}}
# {'_id': ObjectId('6415303a9e36d615850b3e6d'),
#  'geocode': {'latitude': 51.074167, 'longitude': 1.16866}}
# {'_id': ObjectId('6415303a9e36d615850b3e6e'),
#  'geocode': {'latitude': 51.091129, 'longitude': 1.186289}}
# {'_id': ObjectId('6415303a9e36d615850b3e70'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'_id': ObjectId('6415303a9e36d615850b3e71'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'_id': ObjectId('6415303a9e36d615850b3e72'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'_id': ObjectId('6415303a9e36d615850b3e73'),
#  'geocode': {'latitude': 51.080171, 'longitude': 1.175782}}
# {'_id': ObjectId('6415303a9e36d615850b3e74'),
#  'geocode': {'latitude': 51.077414, 'longitude': 1.172652}}
# {'_id': ObjectId('6415303a9e36d615850b3e75'),
#  'geocode': {'latitude': 51.090286, 'longitude': 1.185859}}
# {'_id': ObjectId('6415303a9e36d615850b3e76'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'_id': ObjectId('6415303a9e36d615850b3e77'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'_id': ObjectId('6415303a9e36d615850b3e78'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'_id': ObjectId('6415303a9e36d615850b3e79'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'_id': ObjectId('6415303a9e36d615850b3e7a'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'_id': ObjectId('6415303a9e36d615850b3e7b'),
#  'geocode': {'latitude': 51.082871, 'longitude': 1.177367}}
# {'_id': ObjectId('6415303a9e36d615850b3e7c'),
#  'geocode': {'latitude': 51.078068, 'longitude': 1.172054}}
# {'_id': ObjectId('6415303a9e36d615850b3e7d'),
#  'geocode': {'latitude': 51.082381, 'longitude': 1.176219}}
# {'_id': ObjectId('6415303a9e36d615850b3e7e'),
#  'geocode': {'latitude': 51.078885, 'longitude': 1.172452}}
# {'_id': ObjectId('6415303a9e36d615850b3e7f'),
#  'geocode': {'latitude': 51.07623, 'longitude': 1.169515}}
# {'_id': ObjectId('6415303a9e36d615850b3e80'),
#  'geocode': {'latitude': 51.085038, 'longitude': 1.177729}}
# {'_id': ObjectId('6415303a9e36d615850b3e81'),
#  'geocode': {'latitude': 51.07623, 'longitude': 1.169515}}
# {'_id': ObjectId('6415303a9e36d615850b3e82'),
#  'geocode': {'latitude': 51.081154, 'longitude': 1.174678}}
# {'_id': ObjectId('6415303a9e36d615850b3e83'),
#  'geocode': {'latitude': 51.075403, 'longitude': 1.168516}}
# {'_id': ObjectId('6415303a9e36d615850b3e84'),
#  'geocode': {'latitude': 51.085038, 'longitude': 1.177729}}
# {'_id': ObjectId('6415303a9e36d615850b3e85'),
#  'geocode': {'latitude': 51.078874, 'longitude': 1.171552}}
# {'_id': ObjectId('6415303a9e36d615850b3e86'),
#  'geocode': {'latitude': 51.0819, 'longitude': 1.17373}}
# {'_id': ObjectId('6415303a9e36d615850b3e87'),
#  'geocode': {'latitude': 51.077243, 'longitude': 1.168984}}
# {'_id': ObjectId('6415303a9e36d615850b3e88'),
#  'geocode': {'latitude': 51.081291, 'longitude': 1.173631}}
# {'_id': ObjectId('6415303a9e36d615850b3e89'),
#  'geocode': {'latitude': 51.088893, 'longitude': 1.181507}}
# {'_id': ObjectId('6415303a9e36d615850b3e8a'),
#  'geocode': {'latitude': 51.087034, 'longitude': 1.178766}}
# {'_id': ObjectId('6415303a9e36d615850b3e8b'),
#  'geocode': {'latitude': 51.086485, 'longitude': 1.178428}}
# {'_id': ObjectId('6415303a9e36d615850b3e8c'),
#  'geocode': {'latitude': 51.088124, 'longitude': 1.179997}}
# {'_id': ObjectId('6415303a9e36d615850b3e8d'),
#  'geocode': {'latitude': 51.088125, 'longitude': 1.179998}}
# {'_id': ObjectId('6415303a9e36d615850b3e8e'),
#  'geocode': {'latitude': 51.08129, 'longitude': 1.17363}}
# {'_id': ObjectId('6415303a9e36d615850b3e8f'),
#  'geocode': {'latitude': 51.087034, 'longitude': 1.178766}}
# {'_id': ObjectId('6415303a9e36d615850b3e90'),
#  'geocode': {'latitude': 51.080533, 'longitude': 1.172065}}
# {'_id': ObjectId('6415303a9e36d615850b3e91'),
#  'geocode': {'latitude': 51.087034, 'longitude': 1.178766}}
# {'_id': ObjectId('6415303a9e36d615850b3e92'),
#  'geocode': {'latitude': 51.085872, 'longitude': 1.177515}}
# {'_id': ObjectId('6415303a9e36d615850b3e93'),
#  'geocode': {'latitude': 51.085365, 'longitude': 1.176952}}
# {'_id': ObjectId('6415303a9e36d615850b3e95'),
#  'geocode': {'latitude': 51.085038, 'longitude': 1.177729}}
# {'_id': ObjectId('6415303a9e36d615850b3e96'),
#  'geocode': {'latitude': 51.080302, 'longitude': 1.171635}}
# {'_id': ObjectId('6415303a9e36d615850b3e97'),
#  'geocode': {'latitude': 51.090168, 'longitude': 1.181609}}
# {'_id': ObjectId('6415303a9e36d615850b3e99'),
#  'geocode': {'latitude': 51.077289, 'longitude': 1.168302}}
# {'_id': ObjectId('6415303a9e36d615850b3e9a'),
#  'geocode': {'latitude': 51.085001, 'longitude': 1.177755}}
# {'_id': ObjectId('6415303a9e36d615850b3e9b'),
#  'geocode': {'latitude': 51.079192, 'longitude': 1.173416}}
# {'_id': ObjectId('6415303a9e36d615850b3e9c'),
#  'geocode': {'latitude': 51.08885, 'longitude': 1.180133}}
# {'_id': ObjectId('6415303a9e36d615850b3e9d'),
#  'geocode': {'latitude': 51.082332, 'longitude': 1.17306}}
# {'_id': ObjectId('6415303a9e36d615850b3e9e'),
#  'geocode': {'latitude': 51.082331, 'longitude': 1.173059}}
# {'_id': ObjectId('6415303a9e36d615850b3e9f'),
#  'geocode': {'latitude': 51.088806, 'longitude': 1.180073}}
# {'_id': ObjectId('6415303a9e36d615850b3ea0'),
#  'geocode': {'latitude': 51.081795, 'longitude': 1.172295}}
# {'_id': ObjectId('6415303a9e36d615850b3ea1'),
#  'geocode': {'latitude': 51.07555, 'longitude': 1.165413}}
# {'_id': ObjectId('6415303a9e36d615850b3ea2'),
#  'geocode': {'latitude': 51.077737, 'longitude': 1.167704}}
# {'_id': ObjectId('6415303a9e36d615850b3ea3'),
#  'geocode': {'latitude': 51.085553, 'longitude': 1.175337}}
# {'_id': ObjectId('6415303a9e36d615850b3ea4'),
#  'geocode': {'latitude': 51.0769439, 'longitude': 1.1665238}}
# {'_id': ObjectId('6415303a9e36d615850b3ea5'),
#  'geocode': {'latitude': 51.0932246, 'longitude': 1.1829433}}
# {'_id': ObjectId('6415303a9e36d615850b3ea6'),
#  'geocode': {'latitude': 51.0817527770996, 'longitude': 1.17090594768524}}
# {'_id': ObjectId('6415303a9e36d615850b3ea7'),
#  'geocode': {'latitude': 51.082374, 'longitude': 1.171506}}
# {'_id': ObjectId('6415303a9e36d615850b3ea8'),
#  'geocode': {'latitude': 51.090195, 'longitude': 1.18094}}
# {'_id': ObjectId('6415303a9e36d615850b3ea9'),
#  'geocode': {'latitude': 51.08186, 'longitude': 1.171556}}
# {'_id': ObjectId('6415303a9e36d615850b3eaa'),
#  'geocode': {'latitude': 51.081291, 'longitude': 1.173631}}
# {'_id': ObjectId('6415303a9e36d615850b3eab'),
#  'geocode': {'latitude': 51.082374, 'longitude': 1.171506}}
# {'_id': ObjectId('6415303a9e36d615850b3ead'),
#  'geocode': {'latitude': 51.076949, 'longitude': 1.164581}}
# {'_id': ObjectId('6415303a9e36d615850b3eae'),
#  'geocode': {'latitude': 51.085552, 'longitude': 1.175336}}
# {'_id': ObjectId('6415303a9e36d615850b3eaf'),
#  'geocode': {'latitude': 51.0751419067383, 'longitude': 1.16350066661835}}
# {'_id': ObjectId('6415303a9e36d615850b3eb0'),
#  'geocode': {'latitude': 51.082374, 'longitude': 1.171506}}
# {'_id': ObjectId('6415303a9e36d615850b3eb1'),
#  'geocode': {'latitude': 51.083812713623, 'longitude': 1.17163395881653}}
# {'_id': ObjectId('6415303a9e36d615850b3eb2'),
#  'geocode': {'latitude': 51.07507, 'longitude': 1.162196}}
# {'_id': ObjectId('6415303a9e36d615850b3eb3'),
#  'geocode': {'latitude': 51.095177, 'longitude': 1.182639}}
# {'_id': ObjectId('6415303a9e36d615850b3eb4'),
#  'geocode': {'latitude': 51.095177, 'longitude': 1.182639}}
# {'_id': ObjectId('6415303a9e36d615850b3eb5'),
#  'geocode': {'latitude': 51.095177, 'longitude': 1.182639}}
# {'_id': ObjectId('6415303a9e36d615850b3eb6'),
#  'geocode': {'latitude': 51.085755, 'longitude': 1.172865}}
# {'_id': ObjectId('6415303a9e36d615850b3eb8'),
#  'geocode': {'latitude': 51.078911, 'longitude': 1.165543}}
# {'_id': ObjectId('6415303a9e36d615850b3eb9'),
#  'geocode': {'latitude': 51.08382, 'longitude': 1.171591}}
# {'_id': ObjectId('6415303a9e36d615850b3ebb'),
#  'geocode': {'latitude': 51.095177, 'longitude': 1.182639}}
# {'_id': ObjectId('6415303a9e36d615850b3ebe'),
#  'geocode': {'latitude': 51.08538, 'longitude': 1.171755}}
# {'_id': ObjectId('6415303a9e36d615850b3ebf'),
#  'geocode': {'latitude': 51.082833, 'longitude': 1.168524}}
# {'_id': ObjectId('6415303a9e36d615850b3ec2'),
#  'geocode': {'latitude': 51.087373, 'longitude': 1.171919}}
# {'_id': ObjectId('6415303a9e36d615850b3ec4'),
#  'geocode': {'latitude': 51.079404, 'longitude': 1.16362}}
# {'_id': ObjectId('6415303a9e36d615850b3ec5'),
#  'geocode': {'latitude': 51.080017, 'longitude': 1.164533}}
# {'_id': ObjectId('6415303a9e36d615850b3ec7'),
#  'geocode': {'latitude': 51.0813407897949, 'longitude': 1.16422498226166}}
# {'_id': ObjectId('6415303a9e36d615850b3ec8'),
#  'geocode': {'latitude': 51.085565, 'longitude': 1.168597}}
# {'_id': ObjectId('6415303a9e36d615850b3ec9'),
#  'geocode': {'latitude': 51.087373, 'longitude': 1.171919}}
# {'_id': ObjectId('6415303a9e36d615850b3ecb'),
#  'geocode': {'latitude': 51.082434, 'longitude': 1.165969}}
# {'_id': ObjectId('6415303a9e36d615850b3ecf'),
#  'geocode': {'latitude': 51.081358, 'longitude': 1.164182}}
# {'_id': ObjectId('6415303a9e36d615850b3ed0'),
#  'geocode': {'latitude': 51.090416, 'longitude': 1.173128}}
# {'_id': ObjectId('6415303a9e36d615850b3ed2'),
#  'geocode': {'latitude': 51.076559, 'longitude': 1.160028}}
# {'_id': ObjectId('6415303a9e36d615850b3ed3'),
#  'geocode': {'latitude': 51.090416, 'longitude': 1.173128}}
# {'_id': ObjectId('6415303a9e36d615850b3ed4'),
#  'geocode': {'latitude': 51.335713, 'longitude': 1.427746}}
# {'_id': ObjectId('6415303a9e36d615850b3ed5'),
#  'geocode': {'latitude': 51.084325, 'longitude': 1.166898}}
# {'_id': ObjectId('6415303a9e36d615850b3ed6'),
#  'geocode': {'latitude': 51.3344841003418, 'longitude': 1.42664802074432}}
# {'_id': ObjectId('6415303a9e36d615850b3ed7'),
#  'geocode': {'latitude': 51.335713, 'longitude': 1.427746}}
# {'_id': ObjectId('6415303a9e36d615850b3ed8'),
#  'geocode': {'latitude': 51.336816, 'longitude': 1.428762}}
# {'_id': ObjectId('6415303a9e36d615850b3ed9'),
#  'geocode': {'latitude': 51.085871, 'longitude': 1.167918}}
# {'_id': ObjectId('6415303a9e36d615850b3eda'),
#  'geocode': {'latitude': 51.084325, 'longitude': 1.166898}}
# {'_id': ObjectId('6415303a9e36d615850b3edb'),
#  'geocode': {'latitude': 51.076715, 'longitude': 1.158282}}
# {'_id': ObjectId('6415303a9e36d615850b3edd'),
#  'geocode': {'latitude': 51.33222, 'longitude': 1.423192}}
# {'_id': ObjectId('6415303a9e36d615850b3ede'),
#  'geocode': {'latitude': 51.338414, 'longitude': 1.429786}}
# {'_id': ObjectId('6415303a9e36d615850b3edf'),
#  'geocode': {'latitude': 51.33222, 'longitude': 1.423192}}
# {'_id': ObjectId('6415303a9e36d615850b3ee0'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'_id': ObjectId('6415303a9e36d615850b3ee1'),
#  'geocode': {'latitude': 51.3322105407715, 'longitude': 1.42320394515991}}
# {'_id': ObjectId('6415303a9e36d615850b3ee2'),
#  'geocode': {'latitude': 51.33222, 'longitude': 1.423192}}
# {'_id': ObjectId('6415303a9e36d615850b3ee3'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'_id': ObjectId('6415303a9e36d615850b3ee4'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'_id': ObjectId('6415303a9e36d615850b3ee5'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'_id': ObjectId('6415303a9e36d615850b3ee6'),
#  'geocode': {'latitude': 51.338414, 'longitude': 1.429786}}
# {'_id': ObjectId('6415303a9e36d615850b3ee7'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'_id': ObjectId('6415303a9e36d615850b3ee8'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'_id': ObjectId('6415303a9e36d615850b3ee9'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'_id': ObjectId('6415303a9e36d615850b3eea'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'_id': ObjectId('6415303a9e36d615850b3eeb'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'_id': ObjectId('6415303a9e36d615850b3eec'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'_id': ObjectId('6415303a9e36d615850b3eed'),
#  'geocode': {'latitude': 51.3322219848633, 'longitude': 1.42319202423096}}
# {'_id': ObjectId('6415303a9e36d615850b3eee'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'_id': ObjectId('6415303a9e36d615850b3eef'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'_id': ObjectId('6415303a9e36d615850b3ef0'),
#  'geocode': {'latitude': 51.092175, 'longitude': 1.173634}}
# {'_id': ObjectId('6415303a9e36d615850b3ef1'),
#  'geocode': {'latitude': 51.3322219848633, 'longitude': 1.42319202423096}}
# {'_id': ObjectId('6415303a9e36d615850b3ef3'),
#  'geocode': {'latitude': 51.331022, 'longitude': 1.421136}}
# {'_id': ObjectId('6415303a9e36d615850b3ef4'),
#  'geocode': {'latitude': 51.3351135253906, 'longitude': 1.42612195014954}}
# {'_id': ObjectId('6415303a9e36d615850b3ef6'),
#  'geocode': {'latitude': 51.332386, 'longitude': 1.421525}}
# {'_id': ObjectId('6415303a9e36d615850b3ef7'),
#  'geocode': {'latitude': 51.349914, 'longitude': 1.440672}}
# {'_id': ObjectId('6415303a9e36d615850b3ef8'),
#  'geocode': {'latitude': 51.332386, 'longitude': 1.421525}}
# {'_id': ObjectId('6415303a9e36d615850b3ef9'),
#  'geocode': {'latitude': 51.332386, 'longitude': 1.421525}}
# {'_id': ObjectId('6415303a9e36d615850b3efa'),
#  'geocode': {'latitude': 51.332386, 'longitude': 1.421525}}
# {'_id': ObjectId('6415303a9e36d615850b3efb'),
#  'geocode': {'latitude': 51.332386, 'longitude': 1.421525}}
# {'_id': ObjectId('6415303a9e36d615850b3efc'),
#  'geocode': {'latitude': 51.087041, 'longitude': 1.168241}}
# {'_id': ObjectId('6415303a9e36d615850b3efd'),
#  'geocode': {'latitude': 51.332495, 'longitude': 1.421188}}
# {'_id': ObjectId('6415303a9e36d615850b3efe'),
#  'geocode': {'latitude': 51.33336, 'longitude': 1.422057}}
# {'_id': ObjectId('6415303a9e36d615850b3eff'),
#  'geocode': {'latitude': 51.343133, 'longitude': 1.432365}}
# {'_id': ObjectId('6415303a9e36d615850b3f00'),
#  'geocode': {'latitude': 51.343133, 'longitude': 1.432364}}
# {'_id': ObjectId('6415303a9e36d615850b3f01'),
#  'geocode': {'latitude': 51.335185, 'longitude': 1.423643}}
# {'_id': ObjectId('6415303a9e36d615850b3f02'),
#  'geocode': {'latitude': 51.335185, 'longitude': 1.423643}}
# {'_id': ObjectId('6415303a9e36d615850b3f03'),
#  'geocode': {'latitude': 51.074546, 'longitude': 1.152994}}
# {'_id': ObjectId('6415303a9e36d615850b3f04'),
#  'geocode': {'latitude': 51.077345, 'longitude': 1.155598}}
# {'_id': ObjectId('6415303a9e36d615850b3f05'),
#  'geocode': {'latitude': 51.33237, 'longitude': 1.420231}}
# {'_id': ObjectId('6415303a9e36d615850b3f06'),
#  'geocode': {'latitude': 51.351811, 'longitude': 1.441044}}
# {'_id': ObjectId('6415303a9e36d615850b3f08'),
#  'geocode': {'latitude': 51.33875, 'longitude': 1.427211}}
# {'_id': ObjectId('6415303a9e36d615850b3f09'),
#  'geocode': {'latitude': 51.33237, 'longitude': 1.420231}}
# {'_id': ObjectId('6415303a9e36d615850b3f0b'),
#  'geocode': {'latitude': 51.334809, 'longitude': 1.422667}}
# {'_id': ObjectId('6415303a9e36d615850b3f0d'),
#  'geocode': {'latitude': 51.3322715759277, 'longitude': 1.41947197914124}}
# {'_id': ObjectId('6415303a9e36d615850b3f0e'),
#  'geocode': {'latitude': 51.3330688476563, 'longitude': 1.42028105258942}}
# {'_id': ObjectId('6415303a9e36d615850b3f0f'),
#  'geocode': {'latitude': 51.33308, 'longitude': 1.42027}}
# {'_id': ObjectId('6415303a9e36d615850b3f10'),
#  'geocode': {'latitude': 51.33308, 'longitude': 1.42027}}
# {'_id': ObjectId('6415303a9e36d615850b3f12'),
#  'geocode': {'latitude': 51.33308, 'longitude': 1.42027}}
# {'_id': ObjectId('6415303a9e36d615850b3f13'),
#  'geocode': {'latitude': 51.352901, 'longitude': 1.440982}}
# {'_id': ObjectId('6415303a9e36d615850b3f14'),
#  'geocode': {'latitude': 51.33308, 'longitude': 1.42027}}
# {'_id': ObjectId('6415303a9e36d615850b3f15'),
#  'geocode': {'latitude': 51.332515, 'longitude': 1.419581}}
# {'_id': ObjectId('6415303a9e36d615850b3f17'),
#  'geocode': {'latitude': 51.330413, 'longitude': 1.417328}}
# {'_id': ObjectId('6415303a9e36d615850b3f18'),
#  'geocode': {'latitude': 51.3310761, 'longitude': 1.4179475}}
# {'_id': ObjectId('6415303a9e36d615850b3f19'),
#  'geocode': {'latitude': 51.330413, 'longitude': 1.417328}}
# {'_id': ObjectId('6415303a9e36d615850b3f1a'),
#  'geocode': {'latitude': 51.330413, 'longitude': 1.417328}}
# {'_id': ObjectId('6415303a9e36d615850b3f1b'),
#  'geocode': {'latitude': 51.3332063, 'longitude': 1.4201594}}
# {'_id': ObjectId('6415303a9e36d615850b3f1c'),
#  'geocode': {'latitude': 51.330413, 'longitude': 1.417328}}
# {'_id': ObjectId('6415303a9e36d615850b3f1d'),
#  'geocode': {'latitude': 51.333009, 'longitude': 1.419934}}
# {'_id': ObjectId('6415303a9e36d615850b3f1e'),
#  'geocode': {'latitude': 51.333009, 'longitude': 1.419934}}
# {'_id': ObjectId('6415303a9e36d615850b3f1f'),
#  'geocode': {'latitude': 51.333009, 'longitude': 1.419934}}
# {'_id': ObjectId('6415303a9e36d615850b3f20'),
#  'geocode': {'latitude': 51.333009, 'longitude': 1.419934}}
# {'_id': ObjectId('6415303a9e36d615850b3f21'),
#  'geocode': {'latitude': 51.333009, 'longitude': 1.419934}}
# {'_id': ObjectId('6415303a9e36d615850b3f22'),
#  'geocode': {'latitude': 51.333009, 'longitude': 1.419934}}
# {'_id': ObjectId('6415303a9e36d615850b3f23'),
#  'geocode': {'latitude': 51.333152, 'longitude': 1.4198331}}
# {'_id': ObjectId('6415303a9e36d615850b3f24'),
#  'geocode': {'latitude': 51.086577, 'longitude': 1.163467}}
# {'_id': ObjectId('6415303a9e36d615850b3f25'),
#  'geocode': {'latitude': 51.333009, 'longitude': 1.419934}}
# {'_id': ObjectId('6415303a9e36d615850b3f26'),
#  'geocode': {'latitude': 51.0737868, 'longitude': 1.1503712}}
# {'_id': ObjectId('6415303a9e36d615850b3f27'),
#  'geocode': {'latitude': 51.333918, 'longitude': 1.420835}}
# {'_id': ObjectId('6415303a9e36d615850b3f28'),
#  'geocode': {'latitude': 51.3341272, 'longitude': 1.4206587}}
# {'_id': ObjectId('6415303a9e36d615850b3f29'),
#  'geocode': {'latitude': 51.332812, 'longitude': 1.419273}}
# {'_id': ObjectId('6415303a9e36d615850b3f2a'),
#  'geocode': {'latitude': 51.332812, 'longitude': 1.419273}}
# {'_id': ObjectId('6415303a9e36d615850b3f2b'),
#  'geocode': {'latitude': 51.332812, 'longitude': 1.419273}}
# {'_id': ObjectId('6415303a9e36d615850b3f2c'),
#  'geocode': {'latitude': 51.332812, 'longitude': 1.419273}}
# {'_id': ObjectId('6415303a9e36d615850b3f2d'),
#  'geocode': {'latitude': 51.332812, 'longitude': 1.419273}}
# {'_id': ObjectId('6415303a9e36d615850b3f2e'),
#  'geocode': {'latitude': 51.332812, 'longitude': 1.419273}}
# {'_id': ObjectId('6415303a9e36d615850b3f2f'),
#  'geocode': {'latitude': 51.332812, 'longitude': 1.419273}}
# {'_id': ObjectId('6415303a9e36d615850b3f30'),
#  'geocode': {'latitude': 51.332812, 'longitude': 1.419273}}
# {'_id': ObjectId('6415303a9e36d615850b3f31'),
#  'geocode': {'latitude': 51.332812, 'longitude': 1.419273}}
# {'_id': ObjectId('6415303a9e36d615850b3f32'),
#  'geocode': {'latitude': 51.331827, 'longitude': 1.418209}}
# {'_id': ObjectId('6415303a9e36d615850b3f33'),
#  'geocode': {'latitude': 51.332812, 'longitude': 1.419273}}
# {'_id': ObjectId('6415303a9e36d615850b3f34'),
#  'geocode': {'latitude': 51.3338775634766, 'longitude': 1.42038595676422}}
# {'_id': ObjectId('6415303a9e36d615850b3f35'),
#  'geocode': {'latitude': 51.331827, 'longitude': 1.418209}}
# {'_id': ObjectId('6415303a9e36d615850b3f36'),
#  'geocode': {'latitude': 51.33442, 'longitude': 1.420872}}
# {'_id': ObjectId('6415303a9e36d615850b3f37'),
#  'geocode': {'latitude': 51.33442, 'longitude': 1.420872}}
# {'_id': ObjectId('6415303a9e36d615850b3f38'),
#  'geocode': {'latitude': 51.331827, 'longitude': 1.418209}}
# {'_id': ObjectId('6415303a9e36d615850b3f39'),
#  'geocode': {'latitude': 51.331827, 'longitude': 1.418209}}
# {'_id': ObjectId('6415303a9e36d615850b3f3a'),
#  'geocode': {'latitude': 51.331827, 'longitude': 1.418209}}
# {'_id': ObjectId('6415303a9e36d615850b3f3b'),
#  'geocode': {'latitude': 51.333774, 'longitude': 1.420221}}
# {'_id': ObjectId('6415303a9e36d615850b3f3c'),
#  'geocode': {'latitude': 51.3328557, 'longitude': 1.4192286}}
# {'_id': ObjectId('6415303a9e36d615850b3f3d'),
#  'geocode': {'latitude': 51.3348208, 'longitude': 1.4212417}}
# {'_id': ObjectId('6415303a9e36d615850b3f3e'),
#  'geocode': {'latitude': 51.3348734, 'longitude': 1.4212887}}
# {'_id': ObjectId('6415303a9e36d615850b3f40'),
#  'geocode': {'latitude': 51.3373565673828, 'longitude': 1.42377603054047}}
# {'_id': ObjectId('6415303a9e36d615850b3f41'),
#  'geocode': {'latitude': 51.3319, 'longitude': 1.418171}}
# ...
# {'_id': ObjectId('6415303b9e36d615850ba0f9'),
#  'geocode': {'latitude': 51.556071, 'longitude': 0.250707}}
# {'_id': ObjectId('6415303b9e36d615850ba0fa'),
#  'geocode': {'latitude': 51.556071, 'longitude': 0.250707}}
# {'_id': ObjectId('6415303b9e36d615850ba0fb'),
#  'geocode': {'latitude': 51.556071, 'longitude': 0.250707}}
# {'_id': ObjectId('6415303b9e36d615850ba0fc'),
#  'geocode': {'latitude': 51.335107, 'longitude': 0.028452}}
# {'_id': ObjectId('6415303b9e36d615850ba0fd'),
#  'geocode': {'latitude': 51.773286, 'longitude': 0.472545}}
# {'_id': ObjectId('6415303b9e36d615850ba0fe'),
#  'geocode': {'latitude': 51.5536533, 'longitude': 0.2481306}}
# {'_id': ObjectId('6415303b9e36d615850ba0ff'),
#  'geocode': {'latitude': 51.460156, 'longitude': 0.153763}}
# {'_id': ObjectId('6415303b9e36d615850ba100'),
#  'geocode': {'latitude': 51.384142, 'longitude': 0.077414}}
# {'_id': ObjectId('6415303b9e36d615850ba101'),
#  'geocode': {'latitude': 51.481647, 'longitude': 0.175329}}
# {'_id': ObjectId('6415303b9e36d615850ba102'),
#  'geocode': {'latitude': 51.726835, 'longitude': 0.424726}}
# {'_id': ObjectId('6415303b9e36d615850ba103'),
#  'geocode': {'latitude': 51.556438, 'longitude': 0.250812}}
# {'_id': ObjectId('6415303b9e36d615850ba104'),
#  'geocode': {'latitude': 51.556438, 'longitude': 0.250812}}
# {'_id': ObjectId('6415303b9e36d615850ba105'),
#  'geocode': {'latitude': 51.726835, 'longitude': 0.424726}}
# {'_id': ObjectId('6415303b9e36d615850ba106'),
#  'geocode': {'latitude': 51.556438, 'longitude': 0.250812}}
# {'_id': ObjectId('6415303b9e36d615850ba107'),
#  'geocode': {'latitude': 51.556438, 'longitude': 0.250812}}
# {'_id': ObjectId('6415303b9e36d615850ba108'),
#  'geocode': {'latitude': 51.556438, 'longitude': 0.250812}}
# {'_id': ObjectId('6415303b9e36d615850ba109'),
#  'geocode': {'latitude': 51.556438, 'longitude': 0.250812}}
# {'_id': ObjectId('6415303b9e36d615850ba10a'),
#  'geocode': {'latitude': 51.556438, 'longitude': 0.250812}}
# {'_id': ObjectId('6415303b9e36d615850ba10b'),
#  'geocode': {'latitude': 51.556438, 'longitude': 0.250812}}
# {'_id': ObjectId('6415303b9e36d615850ba10c'),
#  'geocode': {'latitude': 51.556438, 'longitude': 0.250811}}
# {'_id': ObjectId('6415303b9e36d615850ba10d'),
#  'geocode': {'latitude': 51.877006, 'longitude': 0.579519}}
# {'_id': ObjectId('6415303b9e36d615850ba10e'),
#  'geocode': {'latitude': 51.6668778, 'longitude': 0.3631793}}
# {'_id': ObjectId('6415303b9e36d615850ba10f'),
#  'geocode': {'latitude': 51.554074, 'longitude': 0.248387}}
# {'_id': ObjectId('6415303b9e36d615850ba110'),
#  'geocode': {'latitude': 51.554074, 'longitude': 0.248387}}
# {'_id': ObjectId('6415303b9e36d615850ba111'),
#  'geocode': {'latitude': 51.554074, 'longitude': 0.248387}}
# {'_id': ObjectId('6415303b9e36d615850ba112'),
#  'geocode': {'latitude': 51.554074, 'longitude': 0.248387}}
# {'_id': ObjectId('6415303b9e36d615850ba113'),
#  'geocode': {'latitude': 51.554074, 'longitude': 0.248387}}
# {'_id': ObjectId('6415303b9e36d615850ba114'),
#  'geocode': {'latitude': 51.554074, 'longitude': 0.248387}}
# {'_id': ObjectId('6415303b9e36d615850ba115'),
#  'geocode': {'latitude': 51.561788, 'longitude': 0.2561944}}
# {'_id': ObjectId('6415303b9e36d615850ba116'),
#  'geocode': {'latitude': 51.554074, 'longitude': 0.248387}}
# {'_id': ObjectId('6415303b9e36d615850ba117'),
#  'geocode': {'latitude': 51.554074, 'longitude': 0.248387}}
# {'_id': ObjectId('6415303b9e36d615850ba118'),
#  'geocode': {'latitude': 51.554074, 'longitude': 0.248387}}
# {'_id': ObjectId('6415303b9e36d615850ba119'),
#  'geocode': {'latitude': 51.729217, 'longitude': 0.426997}}
# {'_id': ObjectId('6415303b9e36d615850ba11a'),
#  'geocode': {'latitude': 51.552966, 'longitude': 0.247092}}
# {'_id': ObjectId('6415303b9e36d615850ba11b'),
#  'geocode': {'latitude': 51.601489, 'longitude': 0.296477}}
# {'_id': ObjectId('6415303b9e36d615850ba11c'),
#  'geocode': {'latitude': 51.5542339, 'longitude': 0.2484556}}
# {'_id': ObjectId('6415303b9e36d615850ba11d'),
#  'geocode': {'latitude': 51.552966, 'longitude': 0.247092}}
# {'_id': ObjectId('6415303b9e36d615850ba11e'),
#  'geocode': {'latitude': 51.552966, 'longitude': 0.247092}}
# {'_id': ObjectId('6415303b9e36d615850ba11f'),
#  'geocode': {'latitude': 51.552966, 'longitude': 0.247092}}
# {'_id': ObjectId('6415303b9e36d615850ba120'),
#  'geocode': {'latitude': 51.552966, 'longitude': 0.247092}}
# {'_id': ObjectId('6415303b9e36d615850ba121'),
#  'geocode': {'latitude': 51.728351, 'longitude': 0.425792}}
# {'_id': ObjectId('6415303b9e36d615850ba122'),
#  'geocode': {'latitude': 51.553429, 'longitude': 0.247316}}
# {'_id': ObjectId('6415303b9e36d615850ba123'),
#  'geocode': {'latitude': 51.552966, 'longitude': 0.247092}}
# {'_id': ObjectId('6415303b9e36d615850ba124'),
#  'geocode': {'latitude': 51.555006, 'longitude': 0.2489163}}
# {'_id': ObjectId('6415303b9e36d615850ba125'),
#  'geocode': {'latitude': 51.553429, 'longitude': 0.247316}}
# {'_id': ObjectId('6415303b9e36d615850ba126'),
#  'geocode': {'latitude': 51.553429, 'longitude': 0.247316}}
# {'_id': ObjectId('6415303b9e36d615850ba127'),
#  'geocode': {'latitude': 51.553429, 'longitude': 0.247316}}
# {'_id': ObjectId('6415303b9e36d615850ba128'),
#  'geocode': {'latitude': 51.553429, 'longitude': 0.247316}}
# {'_id': ObjectId('6415303b9e36d615850ba129'),
#  'geocode': {'latitude': 51.5550546, 'longitude': 0.2489487}}
# {'_id': ObjectId('6415303b9e36d615850ba12a'),
#  'geocode': {'latitude': 51.55515, 'longitude': 0.249017}}
# {'_id': ObjectId('6415303b9e36d615850ba12b'),
#  'geocode': {'latitude': 51.8693961, 'longitude': 0.5710759}}
# {'_id': ObjectId('6415303b9e36d615850ba12c'),
#  'geocode': {'latitude': 51.8807792663574, 'longitude': 0.58288699388504}}
# {'_id': ObjectId('6415303b9e36d615850ba12d'),
#  'geocode': {'latitude': 51.8693961, 'longitude': 0.5710759}}
# {'_id': ObjectId('6415303b9e36d615850ba12e'),
#  'geocode': {'latitude': 51.55515, 'longitude': 0.249017}}
# {'_id': ObjectId('6415303b9e36d615850ba12f'),
#  'geocode': {'latitude': 51.629025, 'longitude': 0.32392}}
# {'_id': ObjectId('6415303b9e36d615850ba130'),
#  'geocode': {'latitude': 51.8693961, 'longitude': 0.5710759}}
# {'_id': ObjectId('6415303b9e36d615850ba131'),
#  'geocode': {'latitude': 51.4813443, 'longitude': 0.1741874}}
# {'_id': ObjectId('6415303b9e36d615850ba132'),
#  'geocode': {'latitude': 51.465711, 'longitude': 0.158287}}
# {'_id': ObjectId('6415303b9e36d615850ba133'),
#  'geocode': {'latitude': 51.464466, 'longitude': 0.157076}}
# {'_id': ObjectId('6415303b9e36d615850ba134'),
#  'geocode': {'latitude': 51.465712, 'longitude': 0.158287}}
# {'_id': ObjectId('6415303b9e36d615850ba135'),
#  'geocode': {'latitude': 51.522316, 'longitude': 0.215526}}
# {'_id': ObjectId('6415303b9e36d615850ba136'),
#  'geocode': {'latitude': 51.465712, 'longitude': 0.158287}}
# {'_id': ObjectId('6415303b9e36d615850ba137'),
#  'geocode': {'latitude': 51.465712, 'longitude': 0.158287}}
# {'_id': ObjectId('6415303b9e36d615850ba138'),
#  'geocode': {'latitude': 51.465712, 'longitude': 0.158287}}
# {'_id': ObjectId('6415303b9e36d615850ba139'),
#  'geocode': {'latitude': 51.406223, 'longitude': 0.098429}}
# {'_id': ObjectId('6415303b9e36d615850ba13a'),
#  'geocode': {'latitude': 51.4657135009766, 'longitude': 0.15828700363636}}
# {'_id': ObjectId('6415303b9e36d615850ba13b'),
#  'geocode': {'latitude': 51.406223, 'longitude': 0.098429}}
# {'_id': ObjectId('6415303b9e36d615850ba13c'),
#  'geocode': {'latitude': 51.555936, 'longitude': 0.24933}}
# {'_id': ObjectId('6415303b9e36d615850ba13d'),
#  'geocode': {'latitude': 51.879121, 'longitude': 0.580686}}
# {'_id': ObjectId('6415303b9e36d615850ba13e'),
#  'geocode': {'latitude': 51.555936, 'longitude': 0.24933}}
# {'_id': ObjectId('6415303b9e36d615850ba13f'),
#  'geocode': {'latitude': 51.555980682373, 'longitude': 0.249357998371124}}
# {'_id': ObjectId('6415303b9e36d615850ba140'),
#  'geocode': {'latitude': 51.3972854614258, 'longitude': 0.0893519967794418}}
# {'_id': ObjectId('6415303b9e36d615850ba141'),
#  'geocode': {'latitude': 51.4655151367188, 'longitude': 0.157817006111145}}
# {'_id': ObjectId('6415303b9e36d615850ba142'),
#  'geocode': {'latitude': 51.571894, 'longitude': 0.265429}}
# {'_id': ObjectId('6415303b9e36d615850ba143'),
#  'geocode': {'latitude': 51.465523, 'longitude': 0.157818}}
# {'_id': ObjectId('6415303b9e36d615850ba144'),
#  'geocode': {'latitude': 51.465523, 'longitude': 0.157818}}
# {'_id': ObjectId('6415303b9e36d615850ba145'),
#  'geocode': {'latitude': 51.457912, 'longitude': 0.150102}}
# {'_id': ObjectId('6415303b9e36d615850ba146'),
#  'geocode': {'latitude': 51.457913, 'longitude': 0.150103}}
# {'_id': ObjectId('6415303b9e36d615850ba147'),
#  'geocode': {'latitude': 51.8694691, 'longitude': 0.5705142}}
# {'_id': ObjectId('6415303b9e36d615850ba148'),
#  'geocode': {'latitude': 51.8694691, 'longitude': 0.5705142}}
# {'_id': ObjectId('6415303b9e36d615850ba149'),
#  'geocode': {'latitude': 51.8694691, 'longitude': 0.5705142}}
# {'_id': ObjectId('6415303b9e36d615850ba14a'),
#  'geocode': {'latitude': 51.730834, 'longitude': 0.427518}}
# {'_id': ObjectId('6415303b9e36d615850ba14b'),
#  'geocode': {'latitude': 51.8694691, 'longitude': 0.5705142}}
# {'_id': ObjectId('6415303b9e36d615850ba14c'),
#  'geocode': {'latitude': 51.730834, 'longitude': 0.427518}}
# {'_id': ObjectId('6415303b9e36d615850ba14d'),
#  'geocode': {'latitude': 51.730862, 'longitude': 0.427447}}
# {'_id': ObjectId('6415303b9e36d615850ba14e'),
#  'geocode': {'latitude': 51.86999, 'longitude': 0.570953}}
# {'_id': ObjectId('6415303b9e36d615850ba14f'),
#  'geocode': {'latitude': 51.86999, 'longitude': 0.570953}}
# {'_id': ObjectId('6415303b9e36d615850ba150'),
#  'geocode': {'latitude': 51.86999, 'longitude': 0.570953}}
# {'_id': ObjectId('6415303b9e36d615850ba151'),
#  'geocode': {'latitude': 51.86999, 'longitude': 0.570953}}
# {'_id': ObjectId('6415303b9e36d615850ba152'),
#  'geocode': {'latitude': 51.86999, 'longitude': 0.570953}}
# {'_id': ObjectId('6415303b9e36d615850ba153'),
#  'geocode': {'latitude': 51.86999, 'longitude': 0.570953}}
# {'_id': ObjectId('6415303b9e36d615850ba154'),
#  'geocode': {'latitude': 51.86999, 'longitude': 0.570953}}
# {'_id': ObjectId('6415303b9e36d615850ba155'),
#  'geocode': {'latitude': 51.86999, 'longitude': 0.570953}}
# {'_id': ObjectId('6415303b9e36d615850ba156'),
#  'geocode': {'latitude': 51.86999, 'longitude': 0.570953}}
# {'_id': ObjectId('6415303b9e36d615850ba157'),
#  'geocode': {'latitude': 51.8699913024902, 'longitude': 0.570953011512756}}
# {'_id': ObjectId('6415303b9e36d615850ba158'),
#  'geocode': {'latitude': 51.5725353, 'longitude': 0.2658334}}
# {'_id': ObjectId('6415303b9e36d615850ba159'),
#  'geocode': {'latitude': 51.5567359924316, 'longitude': 0.249772995710373}}
# {'_id': ObjectId('6415303b9e36d615850ba15a'),
#  'geocode': {'latitude': 51.556737, 'longitude': 0.249773}}
# {'_id': ObjectId('6415303b9e36d615850ba15b'),
#  'geocode': {'latitude': 51.457059, 'longitude': 0.149098}}
# {'_id': ObjectId('6415303b9e36d615850ba15c'),
#  'geocode': {'latitude': 51.556737, 'longitude': 0.249773}}
# {'_id': ObjectId('6415303b9e36d615850ba15d'),
#  'geocode': {'latitude': 51.556737, 'longitude': 0.249773}}
# {'_id': ObjectId('6415303b9e36d615850ba15e'),
#  'geocode': {'latitude': 51.6294822, 'longitude': 0.323637}}
# {'_id': ObjectId('6415303b9e36d615850ba15f'),
#  'geocode': {'latitude': 51.456159, 'longitude': 0.148091}}
# {'_id': ObjectId('6415303b9e36d615850ba160'),
#  'geocode': {'latitude': 51.456159, 'longitude': 0.148091}}
# {'_id': ObjectId('6415303b9e36d615850ba161'),
#  'geocode': {'latitude': 51.45616, 'longitude': 0.148091}}
# {'_id': ObjectId('6415303b9e36d615850ba162'),
#  'geocode': {'latitude': 51.45616, 'longitude': 0.148091}}
# {'_id': ObjectId('6415303b9e36d615850ba163'),
#  'geocode': {'latitude': 51.62949, 'longitude': 0.323597}}
# {'_id': ObjectId('6415303b9e36d615850ba164'),
#  'geocode': {'latitude': 51.54977, 'longitude': 0.242592}}
# {'_id': ObjectId('6415303b9e36d615850ba165'),
#  'geocode': {'latitude': 51.8700904846191, 'longitude': 0.570897996425629}}
# {'_id': ObjectId('6415303b9e36d615850ba166'),
#  'geocode': {'latitude': 51.62949, 'longitude': 0.323597}}
# {'_id': ObjectId('6415303b9e36d615850ba167'),
#  'geocode': {'latitude': 51.62949, 'longitude': 0.323597}}
# {'_id': ObjectId('6415303b9e36d615850ba168'),
#  'geocode': {'latitude': 51.469768, 'longitude': 0.161718}}
# {'_id': ObjectId('6415303b9e36d615850ba169'),
#  'geocode': {'latitude': 51.469767, 'longitude': 0.161718}}
# {'_id': ObjectId('6415303b9e36d615850ba16a'),
#  'geocode': {'latitude': 51.941637, 'longitude': 0.645198}}
# {'_id': ObjectId('6415303b9e36d615850ba16b'),
#  'geocode': {'latitude': 51.73003, 'longitude': 0.42633}}
# {'_id': ObjectId('6415303b9e36d615850ba16c'),
#  'geocode': {'latitude': 51.435985, 'longitude': 0.127591}}
# {'_id': ObjectId('6415303b9e36d615850ba16d'),
#  'geocode': {'latitude': 51.474245, 'longitude': 0.166149}}
# {'_id': ObjectId('6415303b9e36d615850ba16e'),
#  'geocode': {'latitude': 51.435985, 'longitude': 0.127591}}
# {'_id': ObjectId('6415303b9e36d615850ba16f'),
#  'geocode': {'latitude': 51.435985, 'longitude': 0.127591}}
# {'_id': ObjectId('6415303b9e36d615850ba170'),
#  'geocode': {'latitude': 51.435985, 'longitude': 0.127591}}
# {'_id': ObjectId('6415303b9e36d615850ba171'),
#  'geocode': {'latitude': 51.4554155, 'longitude': 0.1469729}}
# {'_id': ObjectId('6415303b9e36d615850ba172'),
#  'geocode': {'latitude': 51.435985, 'longitude': 0.127591}}
# {'_id': ObjectId('6415303b9e36d615850ba173'),
#  'geocode': {'latitude': 51.435985, 'longitude': 0.127591}}
# {'_id': ObjectId('6415303b9e36d615850ba174'),
#  'geocode': {'latitude': 51.436297, 'longitude': 0.12772}}
# {'_id': ObjectId('6415303b9e36d615850ba175'),
#  'geocode': {'latitude': 51.4554155, 'longitude': 0.1469729}}
# {'_id': ObjectId('6415303b9e36d615850ba176'),
#  'geocode': {'latitude': 51.483758, 'longitude': 0.175458}}
# {'_id': ObjectId('6415303b9e36d615850ba177'),
#  'geocode': {'latitude': 51.436297, 'longitude': 0.127721}}
# {'_id': ObjectId('6415303b9e36d615850ba178'),
#  'geocode': {'latitude': 51.556412, 'longitude': 0.248892}}
# {'_id': ObjectId('6415303b9e36d615850ba179'),
#  'geocode': {'latitude': 51.483758, 'longitude': 0.175458}}
# {'_id': ObjectId('6415303b9e36d615850ba17a'),
#  'geocode': {'latitude': 51.557736, 'longitude': 0.250198}}
# {'_id': ObjectId('6415303b9e36d615850ba17b'),
#  'geocode': {'latitude': 51.557736, 'longitude': 0.250198}}
# {'_id': ObjectId('6415303b9e36d615850ba17c'),
#  'geocode': {'latitude': 51.557736, 'longitude': 0.250198}}
# {'_id': ObjectId('6415303b9e36d615850ba17d'),
#  'geocode': {'latitude': 51.5568145, 'longitude': 0.2490997}}
# {'_id': ObjectId('6415303b9e36d615850ba17e'),
#  'geocode': {'latitude': 51.557736, 'longitude': 0.250198}}
# {'_id': ObjectId('6415303b9e36d615850ba17f'),
#  'geocode': {'latitude': 51.602685, 'longitude': 0.295584}}
# {'_id': ObjectId('6415303b9e36d615850ba180'),
#  'geocode': {'latitude': 51.558049, 'longitude': 0.2503}}
# {'_id': ObjectId('6415303b9e36d615850ba181'),
#  'geocode': {'latitude': 51.4549713134766, 'longitude': 0.146105006337166}}
# {'_id': ObjectId('6415303b9e36d615850ba182'),
#  'geocode': {'latitude': 51.556894, 'longitude': 0.249045}}
# {'_id': ObjectId('6415303b9e36d615850ba183'),
#  'geocode': {'latitude': 51.556895, 'longitude': 0.249045}}
# {'_id': ObjectId('6415303b9e36d615850ba184'),
#  'geocode': {'latitude': 51.5584297180176, 'longitude': 0.250535011291504}}
# {'_id': ObjectId('6415303b9e36d615850ba185'),
#  'geocode': {'latitude': 51.454982, 'longitude': 0.146093}}
# {'_id': ObjectId('6415303b9e36d615850ba186'),
#  'geocode': {'latitude': 51.558775, 'longitude': 0.250884}}
# {'_id': ObjectId('6415303b9e36d615850ba187'),
#  'geocode': {'latitude': 51.454982, 'longitude': 0.146093}}
# {'_id': ObjectId('6415303b9e36d615850ba188'),
#  'geocode': {'latitude': 51.558431, 'longitude': 0.250535}}
# {'_id': ObjectId('6415303b9e36d615850ba189'),
#  'geocode': {'latitude': 51.558431, 'longitude': 0.250535}}
# {'_id': ObjectId('6415303b9e36d615850ba18a'),
#  'geocode': {'latitude': 51.558431, 'longitude': 0.250535}}
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
